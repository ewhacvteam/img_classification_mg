# %% [markdown]
# # Data Engineering

# %% [markdown]
# ## Import

# %%
import os
import numpy as np
import cv2
from zipfile import ZipFile
import shutil
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data

# %% [markdown]
# load data function

# %%
# 폴더로부터 이미지를 불러온다.
def image_load(folder, label):
    images = []
    labels = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        img = cv2.imread(img_path)
        if img is not None:
            images.append(img)
            if "climb" == label:
                labels.append(1)
            else:
                labels.append(0)
    return images, labels

# %% [markdown]
# True(Climb)

# %%
climb_images, climb_labels = image_load("/content/drive/MyDrive/BabyProject/CV_img_data/True/true_set", "climb")
#471

# %% [markdown]
# False(not Climb)

# %%
not_climb_images, not_climb_labels = image_load("/content/drive/MyDrive/BabyProject/datas/fasle", "not climb")
#459

# %%
# climb 데이터와 not climb 데이터를 합치기
images = climb_images + not_climb_images
labels = climb_labels + not_climb_labels

# %% [markdown]
# ## 이미지 resize

# %%
def resize_images(images, target_size=(224, 224)):
    resized_images = []
    for img in images:
        resized_img = cv2.resize(img, target_size)
        resized_images.append(resized_img)
    return np.array(resized_images)

# 이미지 크기 조정
resized_images = resize_images(images)

# NumPy 배열로 변환
labels = np.array(labels)

# 데이터셋 분할 (훈련용:검증용:테스트용 = 0.7:0.15:0.15)
train_images, test_images, train_labels, test_labels = train_test_split(resized_images, labels, test_size=0.3, random_state=42, stratify=labels)
val_images, test_images, val_labels, test_labels = train_test_split(test_images, test_labels, test_size=0.5, random_state=42, stratify=test_labels)

# 데이터셋 크기 확인
print("전체 데이터셋 크기:",resized_images.shape)
print("훈련용 데이터셋 크기:", train_images.shape)
print("검증용 데이터셋 크기:", val_images.shape)
print("테스트용 데이터셋 크기:", test_images.shape)
# Out:
# 전체 데이터셋 크기: (930, 224, 224, 3)
# 훈련용 데이터셋 크기: (651, 224, 224, 3)
# 검증용 데이터셋 크기: (139, 224, 224, 3)
# 테스트용 데이터셋 크기: (140, 224, 224, 3)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Augument - flip Data

# %%
def augment_images_and_labels(images, labels):
    augmented_images = []
    augmented_labels = []
    for img, label in zip(images, labels): #label과 이미지 증강 함꼐 처리해야 섞이지 않음
        augmented_images.append(img)  # 원본 이미지 추가
        augmented_labels.append(label)

        flipped_img = cv2.flip(img, 1)  # 좌우 반전 이미지 추가
        augmented_images.append(flipped_img)
        augmented_labels.append(label)
    return np.array(augmented_images), np.array(augmented_labels)

# %%
train_aug_images, train_aug_labels = augment_images_and_labels(train_images, train_labels)
test_aug_images, test_aug_labels = augment_images_and_labels(test_images, test_labels)
val_aug_images, val_aug_labels = augment_images_and_labels(val_images, val_labels)

# %%
# 데이터셋 크기 확인 #이미지 개수 2배 증강됨
print("훈련용 데이터셋 크기:", train_aug_images.shape)
print("검증용 데이터셋 크기:", val_aug_images.shape)
print("테스트용 데이터셋 크기:", test_aug_images.shape)
# Out:
# 훈련용 데이터셋 크기: (1302, 224, 224, 3)
# 검증용 데이터셋 크기: (278, 224, 224, 3)
# 테스트용 데이터셋 크기: (280, 224, 224, 3)

# %% [markdown]
# CannyEdge

# %% [markdown]
# 기본 전처리

# %%
# 이미지 전처리 함수 정의
def preprocess_images(images):
    # 이미지 크기 조정
    resized_images = resize_images(images)
    # VGG16 모델에 맞게 입력 이미지 전처리
    preprocessed_images = preprocess_input(resized_images)
    return preprocessed_images

# 이미지 전처리
train_images_preprocessed = preprocess_images(train_images)
val_images_preprocessed = preprocess_images(val_images)
test_images_preprocessed = preprocess_images(test_images)

# %% [markdown]
# # Model

# %% [markdown]
# ## Import

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Sat May 18 03:08:33 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0              30W /  70W |   8315MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
from keras.applications import VGG16
from keras.models import Model
from keras.layers import Dense, Flatten
from keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Pretrained

# %% [markdown]
# ### 원본 이미지

# %%
# VGG16 모델 불러오기
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# 새로운 분류층 추가
x = base_model.output
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)

# 전체 모델 정의
model = Model(inputs=base_model.input, outputs=predictions)

# VGG16의 가중치는 고정시키고 새로 추가한 층만 훈련
for layer in base_model.layers:
    layer.trainable = False

# 모델 컴파일
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

#early stopping 도입
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 훈련
history = model.fit(train_images, train_labels,
                    batch_size=32, epochs=20,
                    validation_data=(val_images, val_labels),
                    callbacks=[early_stopping]
                    )

# 모델 평가
loss, accuracy = model.evaluate(test_images, test_labels)
print("테스트 데이터셋에서의 손실:", loss)
print("테스트 데이터셋에서의 정확도:", accuracy)
# Out:
# Epoch 1/20
# 21/21 [==============================] - 5s 165ms/step - loss: 1.4239 - accuracy: 0.9462 - val_loss: 2.1006 - val_accuracy: 0.9928
# Epoch 2/20
# 21/21 [==============================] - 3s 151ms/step - loss: 0.0804 - accuracy: 0.9969 - val_loss: 1.4122 - val_accuracy: 0.9712
# Epoch 3/20
# 21/21 [==============================] - 3s 144ms/step - loss: 0.1668 - accuracy: 0.9939 - val_loss: 3.1645 - val_accuracy: 0.9928
# Epoch 4/20
# 21/21 [==============================] - 3s 144ms/step - loss: 0.3133 - accuracy: 0.9969 - val_loss: 1.7063 - val_accuracy: 0.9928
# Epoch 5/20
# 21/21 [==============================] - 3s 150ms/step - loss: 0.0212 - accuracy: 0.9985 - val_loss: 2.6695 - val_accuracy: 0.9928
# Epoch 6/20
# 21/21 [==============================] - 3s 150ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9303 - val_accuracy: 0.9928
# Epoch 7/20
# 21/21 [==============================] - 3s 154ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9614 - val_accuracy: 0.9928
# 5/5 [==============================] - 1s 107ms/step - loss: 0.4422 - accuracy: 0.9857
# 테스트 데이터셋에서의 손실: 0.4422186613082886
# 테스트 데이터셋에서의 정확도: 0.9857142567634583

# %%
# 모델 예측
predictions = model.predict(test_images)
# 확률을 이진 클래스로 변환
predictions_binary = np.where(predictions > 0.5, 1, 0)

# 정밀도, 재현율, F1 스코어 계산
precision = precision_score(test_labels, predictions_binary)
recall = recall_score(test_labels, predictions_binary)
f1 = f1_score(test_labels, predictions_binary)

print("정밀도:", precision)
print("재현율:", recall)
print("F1 스코어:", f1)

#혼동 행렬 생성
cm = confusion_matrix(test_labels,  predictions_binary)
# 혼동 행렬 출력
print("Confusion Matrix:")
print(cm)
# Out:
# 5/5 [==============================] - 1s 126ms/step
# 정밀도: 1.0
# 재현율: 0.971830985915493
# F1 스코어: 0.9857142857142858
# Confusion Matrix:
# [[69  0]
#  [ 2 69]]

# %%
# 학습 과정
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label = 'train loss')
loss_ax.plot(history.history['val_loss'], 'r', label = 'val loss')

acc_ax.plot(history.history['accuracy'], 'b', label = 'train accuracy')
acc_ax.plot(history.history['val_accuracy'], 'g', label = 'val accuracy')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc = 'upper left')
acc_ax.legend(loc = 'lower left')

plt.show()

# %% [markdown]
# ### 이미지 증강처리, 원본 이미지

# %%
# VGG16 모델 불러오기
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# 새로운 분류층 추가
x = base_model.output
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)

# 전체 모델 정의
model = Model(inputs=base_model.input, outputs=predictions)

# VGG16의 가중치는 고정시키고 새로 추가한 층만 훈련
for layer in base_model.layers:
    layer.trainable = False

# 모델 컴파일
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

#early stopping 도입
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 훈련
history = model.fit(train_aug_images, train_aug_labels,
                    batch_size=32, epochs=20,
                    validation_data=(val_aug_images, val_aug_labels),
                    callbacks=[early_stopping])

# 모델 평가
loss, accuracy = model.evaluate(test_aug_images, test_aug_labels)
print("테스트 데이터셋에서의 손실:", loss)
print("테스트 데이터셋에서의 정확도:", accuracy)
# Out:
# Epoch 1/20
# 41/41 [==============================] - 9s 184ms/step - loss: 1.8744 - accuracy: 0.9624 - val_loss: 0.5911 - val_accuracy: 0.9928
# Epoch 2/20
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0352 - accuracy: 0.9985 - val_loss: 0.2888 - val_accuracy: 0.9856
# Epoch 3/20
# 41/41 [==============================] - 6s 154ms/step - loss: 4.2281e-04 - accuracy: 1.0000 - val_loss: 0.3545 - val_accuracy: 0.9856
# Epoch 4/20
# 41/41 [==============================] - 6s 149ms/step - loss: 4.4061e-16 - accuracy: 1.0000 - val_loss: 0.3569 - val_accuracy: 0.9856
# Epoch 5/20
# 41/41 [==============================] - 6s 153ms/step - loss: 4.2281e-16 - accuracy: 1.0000 - val_loss: 0.3569 - val_accuracy: 0.9856
# Epoch 6/20
# 41/41 [==============================] - 6s 154ms/step - loss: 4.2259e-16 - accuracy: 1.0000 - val_loss: 0.3569 - val_accuracy: 0.9856
# Epoch 7/20
# 41/41 [==============================] - 6s 155ms/step - loss: 4.2259e-16 - accuracy: 1.0000 - val_loss: 0.3569 - val_accuracy: 0.9856
# 9/9 [==============================] - 1s 122ms/step - loss: 0.2476 - accuracy: 0.9929
# 테스트 데이터셋에서의 손실: 0.24760189652442932
# 테스트 데이터셋에서의 정확도: 0.9928571581840515

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# 모델 예측
predictions = model.predict(test_aug_images)
# 확률을 이진 클래스로 변환
predictions_binary = np.where(predictions > 0.5, 1, 0)

# 정밀도, 재현율, F1 스코어 계산
precision = precision_score(test_aug_labels, predictions_binary)
recall = recall_score(test_aug_labels, predictions_binary)
f1 = f1_score(test_aug_labels, predictions_binary)

print("정밀도:", precision)
print("재현율:", recall)
print("F1 스코어:", f1)


#혼동 행렬 생성
cm = confusion_matrix(test_aug_labels,  predictions_binary)
# 혼동 행렬 출력
print("Confusion Matrix:")
print(cm)
# Out:
# 9/9 [==============================] - 1s 120ms/step
# 정밀도: 0.9861111111111112
# 재현율: 1.0
# F1 스코어: 0.993006993006993
# Confusion Matrix:
# [[136   2]
#  [  0 142]]

# %%
# 학습 과정
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label = 'train loss')
loss_ax.plot(history.history['val_loss'], 'r', label = 'val loss')

acc_ax.plot(history.history['accuracy'], 'b', label = 'train accuracy')
acc_ax.plot(history.history['val_accuracy'], 'g', label = 'val accuracy')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc = 'upper left')
acc_ax.legend(loc = 'lower left')

plt.show()

# %% [markdown]
# #Build Model

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# 모델 생성
model = Sequential()

# Convolutional Layer와 Pooling Layer 추가
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Fully Connected Layer 추가
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 모델 구조 출력
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_6 (MaxPoolin  (None, 111, 111, 32)      0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_8 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 86528)             0
#
#  dense_30 (Dense)            (None, 256)               22151424
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_31 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 22244929 (84.86 MB)
# Trainable params: 22244929 (84.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Plot Func

# %%
import matplotlib.pyplot as plt

# 훈련 및 검증 손실 시각화
def plot_loss(history):
    plt.plot(history.history['loss'], label='Train loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# 훈련 및 검증 정확도 시각화
def plot_accuracy(history):
    plt.plot(history.history['accuracy'], label='Train accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# 훈련 손실, 정확도 전체 시각화
def plot_hist(history):
  # 학습 과정
  fig, loss_ax = plt.subplots()
  acc_ax = loss_ax.twinx()

  loss_ax.plot(history.history['loss'], 'y', label = 'train loss')
  loss_ax.plot(history.history['val_loss'], 'r', label = 'val loss')

  acc_ax.plot(history.history['accuracy'], 'b', label = 'train accuracy')
  acc_ax.plot(history.history['val_accuracy'], 'g', label = 'val accuracy')

  loss_ax.set_xlabel('epoch')
  loss_ax.set_ylabel('loss')
  acc_ax.set_ylabel('accuracy')

  loss_ax.legend(loc = 'upper left')
  acc_ax.legend(loc = 'lower left')

  plt.show()

# %% [markdown]
# ## 증강 전 원본 이미지

# %%
#early stopping 도입
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# 모델 훈련
history = model.fit(train_images, train_labels,
                    batch_size=32, epochs=100,
                    validation_data=(val_images, val_labels),
                    callbacks=[early_stopping]
                    )

# 모델 평가
loss, accuracy = model.evaluate(test_images, test_labels)
print("테스트 데이터셋에서의 손실:", loss)
print("테스트 데이터셋에서의 정확도:", accuracy)

# 예측 수행
predictions = model.predict(test_images)
predictions = (predictions > 0.50).astype(int)  # 임계값 0.55 적용

# F1 스코어 계산
precision = precision_score(test_labels, predictions)
recall = recall_score(test_labels, predictions)
f1 = f1_score(test_labels, predictions)

print("정밀도:", precision)
print("재현율:", recall)
print("F1 스코어:", f1)

#혼동 행렬 생성
cm = confusion_matrix(test_labels,  predictions)
# 혼동 행렬 출력
print("Confusion Matrix:")
print(cm)

# 모델 훈련 후 시각화
plot_loss(history)
plot_accuracy(history)
plot_hist(history)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 1s 59ms/step - loss: 0.1620 - accuracy: 0.9324 - val_loss: 0.3965 - val_accuracy: 0.8129
# Epoch 2/100
# 21/21 [==============================] - 1s 51ms/step - loss: 0.2190 - accuracy: 0.9217 - val_loss: 0.3657 - val_accuracy: 0.8561
# Epoch 3/100
# 21/21 [==============================] - 1s 50ms/step - loss: 0.1723 - accuracy: 0.9462 - val_loss: 0.3302 - val_accuracy: 0.8201
# Epoch 4/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.5864 - accuracy: 0.9078 - val_loss: 0.4151 - val_accuracy: 0.7914
# Epoch 5/100
# 21/21 [==============================] - 1s 53ms/step - loss: 0.1682 - accuracy: 0.9201 - val_loss: 0.4625 - val_accuracy: 0.8129
# Epoch 6/100
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0575 - accuracy: 0.9647 - val_loss: 0.5923 - val_accuracy: 0.8129
# Epoch 7/100
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0556 - accuracy: 0.9724 - val_loss: 0.6027 - val_accuracy: 0.8561
# Epoch 8/100
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0659 - accuracy: 0.9770 - val_loss: 0.4193 - val_accuracy: 0.8561
# Epoch 9/100
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0432 - accuracy: 0.9877 - val_loss: 0.5736 - val_accuracy: 0.8777
# Epoch 10/100
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0145 - accuracy: 0.9954 - val_loss: 0.5856 - val_accuracy: 0.8993
# Epoch 11/100
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0105 - accuracy: 0.9985 - val_loss: 0.6815 - val_accuracy: 0.8921
# Epoch 12/100
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.4664 - val_accuracy: 0.9281
# Epoch 13/100
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4889 - val_accuracy: 0.9137
# Epoch 14/100
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4205 - val_accuracy: 0.9424
# Epoch 15/100
# 21/21 [==============================] - 1s 48ms/step - loss: 7.8843e-04 - accuracy: 1.0000 - val_loss: 0.5140 - val_accuracy: 0.9137
# Epoch 16/100
# 21/21 [==============================] - 1s 55ms/step - loss: 2.6067e-04 - accuracy: 1.0000 - val_loss: 0.4513 - val_accuracy: 0.9281
# Epoch 17/100
# 21/21 [==============================] - 1s 52ms/step - loss: 5.9320e-04 - accuracy: 1.0000 - val_loss: 0.4898 - val_accuracy: 0.9209
# Epoch 18/100
# 21/21 [==============================] - 1s 56ms/step - loss: 1.8179e-04 - accuracy: 1.0000 - val_loss: 0.4568 - val_accuracy: 0.9281
# Epoch 19/100
# 21/21 [==============================] - 1s 68ms/step - loss: 1.3420e-04 - accuracy: 1.0000 - val_loss: 0.5085 - val_accuracy: 0.9209
# Epoch 20/100
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0664 - accuracy: 0.9877 - val_loss: 0.5816 - val_accuracy: 0.8633
# Epoch 21/100
# 21/21 [==============================] - 1s 67ms/step - loss: 0.0489 - accuracy: 0.9862 - val_loss: 0.5871 - val_accuracy: 0.8201
# Epoch 22/100
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0392 - accuracy: 0.9846 - val_loss: 0.9283 - val_accuracy: 0.8489
# Epoch 23/100
# 21/21 [==============================] - 1s 60ms/step - loss: 0.0755 - accuracy: 0.9662 - val_loss: 0.6800 - val_accuracy: 0.8633
# Epoch 24/100
# 21/21 [==============================] - 1s 61ms/step - loss: 0.0571 - accuracy: 0.9785 - val_loss: 0.7059 - val_accuracy: 0.8561
# Epoch 25/100
# 21/21 [==============================] - 1s 55ms/step - loss: 0.0405 - accuracy: 0.9862 - val_loss: 1.1612 - val_accuracy: 0.8417
# Epoch 26/100
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0304 - accuracy: 0.9908 - val_loss: 1.0561 - val_accuracy: 0.8705
# Epoch 27/100
# 21/21 [==============================] - 1s 54ms/step - loss: 0.0568 - accuracy: 0.9816 - val_loss: 1.0912 - val_accuracy: 0.8201
# Epoch 28/100
# 21/21 [==============================] - 1s 50ms/step - loss: 0.0412 - accuracy: 0.9877 - val_loss: 0.8839 - val_accuracy: 0.8273
# Epoch 29/100
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0257 - accuracy: 0.9939 - val_loss: 1.1072 - val_accuracy: 0.8561
# Epoch 30/100
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0173 - accuracy: 0.9954 - val_loss: 0.8900 - val_accuracy: 0.8921
# Epoch 31/100
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 0.9294 - val_accuracy: 0.8561
# Epoch 32/100
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0079 - accuracy: 0.9954 - val_loss: 1.2665 - val_accuracy: 0.8489
# Epoch 33/100
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0071 - accuracy: 0.9954 - val_loss: 1.4232 - val_accuracy: 0.8489
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6606 - accuracy: 0.8714
# 테스트 데이터셋에서의 손실: 0.6606301665306091
# 테스트 데이터셋에서의 정확도: 0.8714285492897034
# 5/5 [==============================] - 0s 15ms/step
# 정밀도: 0.9206349206349206
# 재현율: 0.8169014084507042
# F1 스코어: 0.8656716417910447
# Confusion Matrix:
# [[64  5]
#  [13 58]]

# %% [markdown]
# ## 증강 후 원본 이미지

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# 모델 생성
model = Sequential()

# Convolutional Layer와 Pooling Layer 추가
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Fully Connected Layer 추가
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 모델 구조 출력
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 222, 222, 32)      896
#
#  max_pooling2d_15 (MaxPooli  (None, 111, 111, 32)      0
#  ng2D)
#
#  conv2d_16 (Conv2D)          (None, 109, 109, 64)      18496
#
#  max_pooling2d_16 (MaxPooli  (None, 54, 54, 64)        0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (None, 52, 52, 128)       73856
#
#  max_pooling2d_17 (MaxPooli  (None, 26, 26, 128)       0
#  ng2D)
#
#  flatten_18 (Flatten)        (None, 86528)             0
#
#  dense_36 (Dense)            (None, 256)               22151424
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_37 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 22244929 (84.86 MB)
# Trainable params: 22244929 (84.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 증강 후 원본 이미지

# early stopping 도입
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# 모델 훈련
history = model.fit(train_aug_images, train_aug_labels,
                    batch_size=32, epochs=200,
                    validation_data=(val_aug_images, val_aug_labels),
                    callbacks=[early_stopping]
                    )

# 모델 평가
loss, accuracy = model.evaluate(test_aug_images, test_aug_labels)
print("테스트 데이터셋에서의 손실:", loss)
print("테스트 데이터셋에서의 정확도:", accuracy)

# 예측 수행
predictions = model.predict(test_aug_images)
predictions = (predictions > 0.50).astype(int)  # 임계값 0.55 적용

# F1 스코어 계산
precision = precision_score(test_aug_labels, predictions)
recall = recall_score(test_aug_labels, predictions)
f1 = f1_score(test_aug_labels, predictions)

print("정밀도:", precision)
print("재현율:", recall)
print("F1 스코어:", f1)

#혼동 행렬 생성
cm = confusion_matrix(test_aug_labels,  predictions)
# 혼동 행렬 출력
print("Confusion Matrix:")
print(cm)

# 모델 훈련 후 시각화
plot_loss(history)
plot_accuracy(history)
plot_hist(history)
# Out:
# Epoch 1/200
# 41/41 [==============================] - 2s 59ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 1.1509 - val_accuracy: 0.8885
# Epoch 2/200
# 41/41 [==============================] - 2s 57ms/step - loss: 6.9040e-04 - accuracy: 1.0000 - val_loss: 1.0586 - val_accuracy: 0.8921
# Epoch 3/200
# 41/41 [==============================] - 2s 53ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 1.1944 - val_accuracy: 0.8957
# Epoch 4/200
# 41/41 [==============================] - 2s 52ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 1.9701 - val_accuracy: 0.8453
# Epoch 5/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 1.1802 - val_accuracy: 0.8741
# Epoch 6/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1087 - val_accuracy: 0.8885
# Epoch 7/200
# 41/41 [==============================] - 2s 56ms/step - loss: 3.3236e-04 - accuracy: 1.0000 - val_loss: 1.1073 - val_accuracy: 0.8885
# Epoch 8/200
# 41/41 [==============================] - 3s 78ms/step - loss: 4.2534e-04 - accuracy: 1.0000 - val_loss: 1.0320 - val_accuracy: 0.8921
# Epoch 9/200
# 41/41 [==============================] - 2s 60ms/step - loss: 0.0506 - accuracy: 0.9946 - val_loss: 1.1233 - val_accuracy: 0.8849
# Epoch 10/200
# 41/41 [==============================] - 3s 65ms/step - loss: 0.0466 - accuracy: 0.9854 - val_loss: 0.9290 - val_accuracy: 0.8705
# Epoch 11/200
# 41/41 [==============================] - 2s 54ms/step - loss: 0.0163 - accuracy: 0.9954 - val_loss: 1.1874 - val_accuracy: 0.8921
# Epoch 12/200
# 41/41 [==============================] - 2s 56ms/step - loss: 0.0268 - accuracy: 0.9962 - val_loss: 1.3085 - val_accuracy: 0.8525
# Epoch 13/200
# 41/41 [==============================] - 2s 60ms/step - loss: 0.0082 - accuracy: 0.9992 - val_loss: 1.2535 - val_accuracy: 0.8705
# Epoch 14/200
# 41/41 [==============================] - 3s 64ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0304 - val_accuracy: 0.8849
# Epoch 15/200
# 41/41 [==============================] - 2s 56ms/step - loss: 5.3842e-04 - accuracy: 1.0000 - val_loss: 1.0059 - val_accuracy: 0.8885
# Epoch 16/200
# 41/41 [==============================] - 2s 59ms/step - loss: 0.0040 - accuracy: 0.9992 - val_loss: 1.0792 - val_accuracy: 0.8849
# Epoch 17/200
# 41/41 [==============================] - 2s 55ms/step - loss: 0.0193 - accuracy: 0.9962 - val_loss: 1.4961 - val_accuracy: 0.8417
# Epoch 18/200
# 41/41 [==============================] - 2s 54ms/step - loss: 0.0197 - accuracy: 0.9954 - val_loss: 1.1014 - val_accuracy: 0.8597
# Epoch 19/200
# 41/41 [==============================] - 3s 63ms/step - loss: 0.0203 - accuracy: 0.9939 - val_loss: 0.8838 - val_accuracy: 0.8921
# Epoch 20/200
# 41/41 [==============================] - 3s 75ms/step - loss: 0.0134 - accuracy: 0.9954 - val_loss: 0.8264 - val_accuracy: 0.8957
# Epoch 21/200
# 41/41 [==============================] - 3s 63ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8369 - val_accuracy: 0.9065
# Epoch 22/200
# 41/41 [==============================] - 2s 59ms/step - loss: 4.3716e-04 - accuracy: 1.0000 - val_loss: 0.8226 - val_accuracy: 0.9065
# Epoch 23/200
# 41/41 [==============================] - 2s 55ms/step - loss: 2.7994e-04 - accuracy: 1.0000 - val_loss: 0.8454 - val_accuracy: 0.9029
# Epoch 24/200
# 41/41 [==============================] - 2s 55ms/step - loss: 3.5205e-04 - accuracy: 1.0000 - val_loss: 0.8637 - val_accuracy: 0.8993
# Epoch 25/200
# 41/41 [==============================] - 2s 51ms/step - loss: 2.0267e-04 - accuracy: 1.0000 - val_loss: 0.8856 - val_accuracy: 0.8993
# Epoch 26/200
# 41/41 [==============================] - 2s 58ms/step - loss: 1.9046e-04 - accuracy: 1.0000 - val_loss: 0.9066 - val_accuracy: 0.8957
# Epoch 27/200
# 41/41 [==============================] - 2s 59ms/step - loss: 1.5780e-04 - accuracy: 1.0000 - val_loss: 0.9054 - val_accuracy: 0.8957
# Epoch 28/200
# 41/41 [==============================] - 2s 56ms/step - loss: 9.5285e-05 - accuracy: 1.0000 - val_loss: 0.9088 - val_accuracy: 0.8993
# Epoch 29/200
# 41/41 [==============================] - 2s 50ms/step - loss: 1.0123e-04 - accuracy: 1.0000 - val_loss: 0.9293 - val_accuracy: 0.8993
# Epoch 30/200
# 41/41 [==============================] - 2s 51ms/step - loss: 1.0115e-04 - accuracy: 1.0000 - val_loss: 0.9224 - val_accuracy: 0.9029
# Epoch 31/200
# 41/41 [==============================] - 2s 49ms/step - loss: 1.8558e-04 - accuracy: 1.0000 - val_loss: 0.9351 - val_accuracy: 0.8993
# Epoch 32/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 1.1380 - val_accuracy: 0.9029
# Epoch 33/200
# 41/41 [==============================] - 2s 52ms/step - loss: 0.0105 - accuracy: 0.9985 - val_loss: 0.9345 - val_accuracy: 0.8921
# Epoch 34/200
# 41/41 [==============================] - 2s 51ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.3222 - val_accuracy: 0.8705
# Epoch 35/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0062 - accuracy: 0.9992 - val_loss: 1.0006 - val_accuracy: 0.8741
# Epoch 36/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0415 - val_accuracy: 0.8741
# Epoch 37/200
# 41/41 [==============================] - 2s 48ms/step - loss: 4.3484e-04 - accuracy: 1.0000 - val_loss: 1.0267 - val_accuracy: 0.8777
# Epoch 38/200
# 41/41 [==============================] - 2s 48ms/step - loss: 2.9139e-04 - accuracy: 1.0000 - val_loss: 1.0589 - val_accuracy: 0.8777
# Epoch 39/200
# 41/41 [==============================] - 2s 49ms/step - loss: 6.4916e-04 - accuracy: 1.0000 - val_loss: 1.1213 - val_accuracy: 0.8741
# Epoch 40/200
# 41/41 [==============================] - 2s 50ms/step - loss: 2.6129e-04 - accuracy: 1.0000 - val_loss: 0.9486 - val_accuracy: 0.8813
# Epoch 41/200
# 41/41 [==============================] - 2s 51ms/step - loss: 0.0049 - accuracy: 0.9977 - val_loss: 1.5834 - val_accuracy: 0.8561
# Epoch 42/200
# 41/41 [==============================] - 2s 52ms/step - loss: 0.0417 - accuracy: 0.9969 - val_loss: 0.8219 - val_accuracy: 0.8957
# Epoch 43/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 1.0828 - val_accuracy: 0.8705
# Epoch 44/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.9686 - val_accuracy: 0.8813
# Epoch 45/200
# 41/41 [==============================] - 2s 51ms/step - loss: 0.0029 - accuracy: 0.9985 - val_loss: 0.7314 - val_accuracy: 0.9101
# Epoch 46/200
# 41/41 [==============================] - 2s 51ms/step - loss: 9.7074e-04 - accuracy: 0.9992 - val_loss: 0.8128 - val_accuracy: 0.9065
# Epoch 47/200
# 41/41 [==============================] - 2s 52ms/step - loss: 5.7999e-05 - accuracy: 1.0000 - val_loss: 0.8366 - val_accuracy: 0.9065
# Epoch 48/200
# 41/41 [==============================] - 2s 50ms/step - loss: 8.0880e-04 - accuracy: 1.0000 - val_loss: 2.6615 - val_accuracy: 0.8489
# Epoch 49/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0407 - accuracy: 0.9854 - val_loss: 1.3374 - val_accuracy: 0.8669
# Epoch 50/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0707 - accuracy: 0.9846 - val_loss: 2.0370 - val_accuracy: 0.8345
# Epoch 51/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.0269 - accuracy: 0.9908 - val_loss: 1.8474 - val_accuracy: 0.8525
# Epoch 52/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0117 - accuracy: 0.9946 - val_loss: 2.3144 - val_accuracy: 0.8381
# Epoch 53/200
# 41/41 [==============================] - 2s 50ms/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 1.7182 - val_accuracy: 0.8597
# Epoch 54/200
# 41/41 [==============================] - 2s 52ms/step - loss: 0.0385 - accuracy: 0.9908 - val_loss: 2.4533 - val_accuracy: 0.8345
# Epoch 55/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.3644 - accuracy: 0.9731 - val_loss: 2.7715 - val_accuracy: 0.8849
# Epoch 56/200
# 41/41 [==============================] - 2s 48ms/step - loss: 1.8533 - accuracy: 0.9071 - val_loss: 2.2834 - val_accuracy: 0.7986
# Epoch 57/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.7606 - accuracy: 0.9178 - val_loss: 0.9435 - val_accuracy: 0.8129
# Epoch 58/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.2047 - accuracy: 0.9439 - val_loss: 1.9917 - val_accuracy: 0.8237
# Epoch 59/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.0993 - accuracy: 0.9677 - val_loss: 1.7113 - val_accuracy: 0.8309
# Epoch 60/200
# 41/41 [==============================] - 2s 52ms/step - loss: 0.0393 - accuracy: 0.9823 - val_loss: 1.6554 - val_accuracy: 0.8273
# Epoch 61/200
# 41/41 [==============================] - 2s 52ms/step - loss: 0.0807 - accuracy: 0.9823 - val_loss: 1.2158 - val_accuracy: 0.8165
# Epoch 62/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0447 - accuracy: 0.9831 - val_loss: 1.4869 - val_accuracy: 0.8165
# Epoch 63/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.0339 - accuracy: 0.9892 - val_loss: 1.5129 - val_accuracy: 0.8597
# Epoch 64/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0568 - accuracy: 0.9846 - val_loss: 1.5659 - val_accuracy: 0.8165
# Epoch 65/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.0413 - accuracy: 0.9900 - val_loss: 1.6443 - val_accuracy: 0.8417
# Epoch 66/200
# 41/41 [==============================] - 2s 50ms/step - loss: 0.0146 - accuracy: 0.9931 - val_loss: 1.7251 - val_accuracy: 0.8597
# Epoch 67/200
# 41/41 [==============================] - 2s 52ms/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 2.3097 - val_accuracy: 0.8237
# Epoch 68/200
# 41/41 [==============================] - 2s 51ms/step - loss: 0.0140 - accuracy: 0.9931 - val_loss: 2.0389 - val_accuracy: 0.8309
# Epoch 69/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.0428 - accuracy: 0.9931 - val_loss: 1.8008 - val_accuracy: 0.8381
# Epoch 70/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0133 - accuracy: 0.9931 - val_loss: 2.4994 - val_accuracy: 0.8273
# Epoch 71/200
# 41/41 [==============================] - 2s 49ms/step - loss: 0.0073 - accuracy: 0.9969 - val_loss: 2.4882 - val_accuracy: 0.8345
# Epoch 72/200
# 41/41 [==============================] - 2s 48ms/step - loss: 0.0140 - accuracy: 0.9939 - val_loss: 3.0042 - val_accuracy: 0.8237
# Epoch 73/200
# 41/41 [==============================] - 2s 51ms/step - loss: 0.0251 - accuracy: 0.9923 - val_loss: 2.6882 - val_accuracy: 0.8273
# Epoch 74/200
# 41/41 [==============================] - 2s 52ms/step - loss: 0.0215 - accuracy: 0.9916 - val_loss: 3.5714 - val_accuracy: 0.8309
# Epoch 75/200
# 41/41 [==============================] - 2s 52ms/step - loss: 0.0225 - accuracy: 0.9931 - val_loss: 2.1218 - val_accuracy: 0.8381
# 9/9 [==============================] - 1s 66ms/step - loss: 1.9606 - accuracy: 0.8893
# 테스트 데이터셋에서의 손실: 1.960607886314392
# 테스트 데이터셋에서의 정확도: 0.8892857432365417
# 9/9 [==============================] - 0s 14ms/step
# 정밀도: 0.9051094890510949
# 재현율: 0.8732394366197183
# F1 스코어: 0.8888888888888888
# Confusion Matrix:
# [[125  13]
#  [ 18 124]]

# %% [markdown]
# ---

# %% [markdown]
# # Canny Edge

# %%
def preprocess_images_with_edge_detection(images):
    preprocessed_images = []
    for image in images:
        # 이미지를 흑백으로 변환
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        # Canny 에지 검출을 통해 에지 감지
        edges = cv2.Canny(gray, threshold1=30, threshold2=100)
        # 에지 이미지를 원본 이미지와 결합하여 새로운 이미지 생성
        edge_image = np.dstack([edges] * 3)
        preprocessed_images.append(edge_image)
    return np.array(preprocessed_images)

# 이미지 전처리
train_images_preprocessed_with_edge = preprocess_images_with_edge_detection(train_images)
val_images_preprocessed_with_edge = preprocess_images_with_edge_detection(val_images)
test_images_preprocessed_with_edge = preprocess_images_with_edge_detection(test_images)

train_aug_images_preprocessed_with_edge = preprocess_images_with_edge_detection(train_aug_images)
val_aug_images_preprocessed_with_edge = preprocess_images_with_edge_detection(val_aug_images)
test_aug_images_preprocessed_with_edge = preprocess_images_with_edge_detection(test_aug_images)

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Original

# %%
# 모델 생성
model = Sequential()

# Convolutional Layer와 Pooling Layer 추가
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Fully Connected Layer 추가
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# early stopping 도입
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# 모델 훈련
history = model.fit(train_images_preprocessed_with_edge, train_labels,
                    batch_size=32, epochs=200,
                    validation_data=(val_images_preprocessed_with_edge, val_labels),
                    callbacks=[early_stopping])

# 모델 평가
loss, accuracy = model.evaluate(test_images_preprocessed_with_edge, test_labels)
print("테스트 데이터셋에서의 손실:", loss)
print("테스트 데이터셋에서의 정확도:", accuracy)

# 예측 수행
predictions = model.predict(test_images_preprocessed_with_edge)
predictions = (predictions > 0.50).astype(int)  # 임계값 0.55 적용

# 정밀도, 재현율, F1 스코어 계산
precision = precision_score(test_labels, predictions)
recall = recall_score(test_labels, predictions)
f1 = f1_score(test_labels, predictions)

print("정밀도:", precision)
print("재현율:", recall)
print("F1 스코어:", f1)

#혼동 행렬 생성
cm = confusion_matrix(test_labels,  predictions)
# 혼동 행렬 출력
print("Confusion Matrix:")
print(cm)

# 모델 훈련 후 시각화
plot_loss(history)
plot_accuracy(history)
plot_hist(history)
# Out:
# Epoch 1/200
# 21/21 [==============================] - 5s 73ms/step - loss: 168.7132 - accuracy: 0.6759 - val_loss: 0.3524 - val_accuracy: 0.8705
# Epoch 2/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.3126 - accuracy: 0.9017 - val_loss: 0.2029 - val_accuracy: 0.9065
# Epoch 3/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0916 - accuracy: 0.9708 - val_loss: 0.1940 - val_accuracy: 0.8993
# Epoch 4/200
# 21/21 [==============================] - 1s 54ms/step - loss: 0.0365 - accuracy: 0.9923 - val_loss: 0.1757 - val_accuracy: 0.9209
# Epoch 5/200
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0232 - accuracy: 0.9939 - val_loss: 0.1798 - val_accuracy: 0.9281
# Epoch 6/200
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0144 - accuracy: 0.9969 - val_loss: 0.2355 - val_accuracy: 0.8849
# Epoch 7/200
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2325 - val_accuracy: 0.9209
# Epoch 8/200
# 21/21 [==============================] - 1s 48ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9209
# Epoch 9/200
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9209
# Epoch 10/200
# 21/21 [==============================] - 1s 50ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2710 - val_accuracy: 0.9281
# Epoch 11/200
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.3033 - val_accuracy: 0.9281
# Epoch 12/200
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3224 - val_accuracy: 0.9209
# Epoch 13/200
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.3411 - val_accuracy: 0.9281
# Epoch 14/200
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.3820 - val_accuracy: 0.9137
# Epoch 15/200
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3604 - val_accuracy: 0.9209
# Epoch 16/200
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4247 - val_accuracy: 0.9281
# Epoch 17/200
# 21/21 [==============================] - 1s 50ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.3388 - val_accuracy: 0.9353
# Epoch 18/200
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2416 - val_accuracy: 0.9353
# Epoch 19/200
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0124 - accuracy: 0.9969 - val_loss: 0.2639 - val_accuracy: 0.8921
# Epoch 20/200
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.3705 - val_accuracy: 0.8849
# Epoch 21/200
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.4072 - val_accuracy: 0.8849
# Epoch 22/200
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3995 - val_accuracy: 0.8921
# Epoch 23/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.5188 - val_accuracy: 0.8777
# Epoch 24/200
# 21/21 [==============================] - 1s 64ms/step - loss: 0.0068 - accuracy: 0.9985 - val_loss: 0.6786 - val_accuracy: 0.8777
# Epoch 25/200
# 21/21 [==============================] - 1s 65ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.3586 - val_accuracy: 0.9065
# Epoch 26/200
# 21/21 [==============================] - 1s 63ms/step - loss: 0.0146 - accuracy: 0.9969 - val_loss: 0.4548 - val_accuracy: 0.9137
# Epoch 27/200
# 21/21 [==============================] - 1s 56ms/step - loss: 0.0286 - accuracy: 0.9923 - val_loss: 0.6740 - val_accuracy: 0.8489
# Epoch 28/200
# 21/21 [==============================] - 1s 58ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.3452 - val_accuracy: 0.9137
# Epoch 29/200
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0073 - accuracy: 0.9985 - val_loss: 0.3232 - val_accuracy: 0.8993
# Epoch 30/200
# 21/21 [==============================] - 1s 55ms/step - loss: 0.0081 - accuracy: 0.9985 - val_loss: 0.5109 - val_accuracy: 0.9065
# Epoch 31/200
# 21/21 [==============================] - 1s 54ms/step - loss: 0.0279 - accuracy: 0.9985 - val_loss: 0.4384 - val_accuracy: 0.8993
# Epoch 32/200
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.3594 - val_accuracy: 0.9065
# Epoch 33/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3843 - val_accuracy: 0.9065
# Epoch 34/200
# 21/21 [==============================] - 1s 64ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.3643 - val_accuracy: 0.8921
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2372 - accuracy: 0.9357
# 테스트 데이터셋에서의 손실: 0.23716259002685547
# 테스트 데이터셋에서의 정확도: 0.9357143044471741
# 5/5 [==============================] - 0s 12ms/step
# 정밀도: 0.918918918918919
# 재현율: 0.9577464788732394
# F1 스코어: 0.9379310344827587
# Confusion Matrix:
# [[63  6]
#  [ 3 68]]

# %% [markdown]
# ### Augmented

# %%
# 모델 생성
model = Sequential()

# Convolutional Layer와 Pooling Layer 추가
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Fully Connected Layer 추가
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# early stopping 도입
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True)

# 모델 훈련
history = model.fit(train_images_preprocessed_with_edge, train_labels,
                    batch_size=32, epochs=200,
                    validation_data=(val_aug_images_preprocessed_with_edge, val_aug_labels),
                    callbacks=[early_stopping])

# 모델 평가
loss, accuracy = model.evaluate(test_aug_images_preprocessed_with_edge, test_aug_labels)
print("테스트 데이터셋에서의 손실:", loss)
print("테스트 데이터셋에서의 정확도:", accuracy)

# 예측 수행
predictions = model.predict(test_aug_images_preprocessed_with_edge)
predictions = (predictions > 0.50).astype(int)  # 임계값 0.55 적용

# 정밀도, 재현율, F1 스코어 계산
precision = precision_score(test_aug_labels, predictions)
recall = recall_score(test_aug_labels, predictions)
f1 = f1_score(test_aug_labels, predictions)

print("정밀도:", precision)
print("재현율:", recall)
print("F1 스코어:", f1)

#혼동 행렬 생성
cm = confusion_matrix(test_aug_labels,  predictions)
# 혼동 행렬 출력
print("Confusion Matrix:")
print(cm)

# 모델 훈련 후 시각화
plot_loss(history)
plot_accuracy(history)
plot_hist(history)
# Out:
# Epoch 1/200
# 21/21 [==============================] - 8s 130ms/step - loss: 177.9801 - accuracy: 0.6559 - val_loss: 0.5565 - val_accuracy: 0.8129
# Epoch 2/200
# 21/21 [==============================] - 1s 59ms/step - loss: 0.6930 - accuracy: 0.8402 - val_loss: 0.4126 - val_accuracy: 0.8381
# Epoch 3/200
# 21/21 [==============================] - 1s 62ms/step - loss: 0.2023 - accuracy: 0.9309 - val_loss: 0.2566 - val_accuracy: 0.8957
# Epoch 4/200
# 21/21 [==============================] - 1s 60ms/step - loss: 0.0871 - accuracy: 0.9724 - val_loss: 0.2522 - val_accuracy: 0.9137
# Epoch 5/200
# 21/21 [==============================] - 1s 62ms/step - loss: 0.0348 - accuracy: 0.9954 - val_loss: 0.2115 - val_accuracy: 0.9209
# Epoch 6/200
# 21/21 [==============================] - 1s 56ms/step - loss: 0.0260 - accuracy: 0.9939 - val_loss: 0.1855 - val_accuracy: 0.9388
# Epoch 7/200
# 21/21 [==============================] - 1s 50ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.2687 - val_accuracy: 0.9101
# Epoch 8/200
# 21/21 [==============================] - 1s 54ms/step - loss: 0.0181 - accuracy: 0.9969 - val_loss: 0.2672 - val_accuracy: 0.9101
# Epoch 9/200
# 21/21 [==============================] - 1s 56ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2898 - val_accuracy: 0.9065
# Epoch 10/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.3712 - val_accuracy: 0.8993
# Epoch 11/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.3866 - val_accuracy: 0.8957
# Epoch 12/200
# 21/21 [==============================] - 1s 50ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.3004 - val_accuracy: 0.9101
# Epoch 13/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2851 - val_accuracy: 0.9173
# Epoch 14/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.3178 - val_accuracy: 0.9137
# Epoch 15/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0087 - accuracy: 0.9985 - val_loss: 1.0178 - val_accuracy: 0.8417
# Epoch 16/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.3221 - val_accuracy: 0.8957
# Epoch 17/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0093 - accuracy: 0.9985 - val_loss: 0.2663 - val_accuracy: 0.9209
# Epoch 18/200
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.2691 - val_accuracy: 0.9173
# Epoch 19/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.3019 - val_accuracy: 0.9281
# Epoch 20/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2969 - val_accuracy: 0.9209
# Epoch 21/200
# 21/21 [==============================] - 1s 55ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.3858 - val_accuracy: 0.8993
# Epoch 22/200
# 21/21 [==============================] - 1s 56ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 0.3811 - val_accuracy: 0.8813
# Epoch 23/200
# 21/21 [==============================] - 1s 54ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.3982 - val_accuracy: 0.8957
# Epoch 24/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0071 - accuracy: 0.9985 - val_loss: 0.3333 - val_accuracy: 0.8957
# Epoch 25/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0077 - accuracy: 0.9985 - val_loss: 0.3316 - val_accuracy: 0.8993
# Epoch 26/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.3821 - val_accuracy: 0.9029
# Epoch 27/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.3718 - val_accuracy: 0.9065
# Epoch 28/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.3900 - val_accuracy: 0.9101
# Epoch 29/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3870 - val_accuracy: 0.9137
# Epoch 30/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4348 - val_accuracy: 0.9065
# Epoch 31/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4327 - val_accuracy: 0.9101
# Epoch 32/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3256 - val_accuracy: 0.9317
# Epoch 33/200
# 21/21 [==============================] - 1s 55ms/step - loss: 2.0946e-04 - accuracy: 1.0000 - val_loss: 0.3614 - val_accuracy: 0.9281
# Epoch 34/200
# 21/21 [==============================] - 1s 56ms/step - loss: 3.1800e-04 - accuracy: 1.0000 - val_loss: 0.3501 - val_accuracy: 0.9209
# Epoch 35/200
# 21/21 [==============================] - 1s 57ms/step - loss: 1.3643e-04 - accuracy: 1.0000 - val_loss: 0.3688 - val_accuracy: 0.9460
# Epoch 36/200
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7333 - val_accuracy: 0.8813
# Epoch 37/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.5856 - val_accuracy: 0.9029
# Epoch 38/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.5155 - val_accuracy: 0.9029
# Epoch 39/200
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5329 - val_accuracy: 0.9029
# Epoch 40/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4466 - val_accuracy: 0.9137
# Epoch 41/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4437 - val_accuracy: 0.9137
# Epoch 42/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 0.9101
# Epoch 43/200
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4634 - val_accuracy: 0.9101
# Epoch 44/200
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4673 - val_accuracy: 0.9173
# Epoch 45/200
# 21/21 [==============================] - 1s 54ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4839 - val_accuracy: 0.9101
# Epoch 46/200
# 21/21 [==============================] - 1s 62ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4502 - val_accuracy: 0.9137
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3158 - accuracy: 0.8821
# 테스트 데이터셋에서의 손실: 0.31583598256111145
# 테스트 데이터셋에서의 정확도: 0.8821428418159485
# 9/9 [==============================] - 0s 22ms/step
# 정밀도: 0.8978102189781022
# 재현율: 0.8661971830985915
# F1 스코어: 0.8817204301075269
# Confusion Matrix:
# [[124  14]
#  [ 19 123]]

# %% [markdown]
# 계속 Val Loss가 매우 낮게 나오는데, 그 이유가 동일한 영상에서 이미지를 추출한 경우에 이미지에 유사성이 많아서 그런 것 같음

# %% [markdown]
# ## Pretrained
